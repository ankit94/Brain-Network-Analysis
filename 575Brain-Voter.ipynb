# %%
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

#settings
pd.options.display.max_columns = 250
pd.options.display.max_rows = 250
sns.set(style="whitegrid")

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_pickle("Brain_data.pkl")

print("Rows: ", df.shape[0])
print("Columns: ", df.shape[1])
# Out:
# Rows:  114
# Columns:  2707

# %%
# variables : Neuroticm Extraversion Openness Agreeableness Conscientiousness FSIQ CAQ

target_variable = 'Sex'

# %%
# Function to categorize the 5 personality values in LOW, MEDIUM, HIGH

def categorizePersonaVal(arr):
    copy = np.array(arr)
    copy.sort()
    n = len(copy)//3
    split1 = copy[n]
    split2 = copy[2*n]
    for i in range(len(arr)):
        if arr[i] <= split1:
            arr[i] = 0
        elif arr[i] <=split2 and arr[i] > split1:
            arr[i] = 1
        elif arr[i] <=copy[-1] and arr[i] > split1:
            arr[i] = 2
        else:
            arr[i] = 0
    return arr

# %%
df[target_variable] = categorizePersonaVal(df[target_variable])

# %%
df.head()
# Out:
#           1         2         3         4          5          6         7  \
# 0  2.835360  2.580988  1.495402  1.200093   0.000000   1.851919  3.484975
# 1  6.554305  5.360270  1.902370  1.574256   0.000000   2.833306  5.254802
# 2  3.694878  2.684327  1.184524  1.385732   0.000000   2.212251  3.960773
# 3  7.246588  5.982223  1.484375  1.581994   0.000000   3.079184  6.493420
# 4  4.082578  6.920282  2.231761  1.498611  17.601711  12.790936  4.045957
#
#           8         9        10         11        12        13        14  \
# 0  3.574244  2.820397  2.644199   3.618953  3.863592  3.872926  4.353500
# 1  9.249994  6.594507  2.921938  10.166893  3.512226  8.659936  7.620572
# 2  8.731869  3.359430  2.402819   6.673786  4.917158  5.740927  4.217348
# 3  7.845961  6.651716  2.879263   8.123113  3.590789  7.464151  3.928595
# 4  4.161073  3.936684  2.570783   4.833147  5.994025  4.779343  6.873526
#
#          15        16        17        18        19        20         21  \
# 0  2.735750  4.348894  2.833179  2.379784  4.523523  4.371820   5.011039
# 1  6.302157  3.214869  3.039218  4.304659  5.973073  5.770001   0.000000
# 2  6.916955  2.841830  3.269311  4.220399  0.000000  3.996138   0.000000
# 3  8.662878  3.567882  2.740998  4.620082  0.000000  6.594481   0.000000
# 4  5.142439  3.914885  2.458179  3.372808  0.000000  7.154727  13.270886
#
#          22        23        24        25        26        27        28  \
# 0  2.998801  1.722205  2.048644  2.981929  4.674295  2.843166  1.739410
# 1  5.619058  1.790914  2.747530  3.919787  5.505054  5.897735  1.939967
# 2  5.444580  1.603834  1.448396  2.486136  4.015531  5.896651  1.424494
# 3  4.078964  2.894646  1.654741  3.682897  4.127917  6.023414  2.800022
# 4  3.349351  1.991614  2.369530  3.421420  5.269713  6.915341  4.022078
#
#          29        30        31         32         33        34        35  \
# 0  3.445935  2.520339  2.968452   0.000000  16.680031  2.835360  1.829554
# 1  4.748871  6.302157  7.961593   0.000000  17.515027  4.932115  5.537891
# 2  2.529404  3.131760  6.096222   0.000000  18.601162  4.041711  3.471508
# 3  4.100569  3.298176  4.840855  15.246152  20.432883  6.673213  3.025723
# 4  3.906497  3.245255  3.580463  29.027043  31.064537  3.573734  2.774636
# 3             2   114   5.0          2            33        37             37
# 4             0    97   5.0         16            35        29             25
#
#    Conscientiousness
# 0                 34
# 1                 32
# 2                 33
# 3                 34
# 4                 28
#
# [5 rows x 2707 columns]

# %%
print(df.Age.value_counts())
ax = sns.countplot(df.Age,label="Count")
# Out:
# 19    25
# 21    16
# 20    11
# 18    11
# 22    10
# 23     9
# 26     7
# 25     7
# 24     7
# 27     5
# 28     4
# 29     2
# Name: Age, dtype: int64

# %%
print(df[target_variable].value_counts())
ax = sns.countplot(df[target_variable],label="Count")
# Out:
# 1    64
# 0    50
# Name: Sex, dtype: int64

# %%
new_df = pd.DataFrame(columns=['ColumnName', 'Null_Count_%', 'Distinct_Values', 'Min', 'Mean', 'Max', 'dtype'])
i = 0
#print(df.shape[0])
for item in df.columns:
    if(df[item].dtype == 'object'):
        new_df.loc[i] = [item, df[item].isnull().sum()/df.shape[0] * 100, df[item].nunique(), "Na", "Na", "Na", df[item].dtype]
    else:
        new_df.loc[i] = [item, df[item].isnull().sum()/df.shape[0] * 100, df[item].nunique(), df[item].min(), df[item].mean(), df[item].max(), df[item].dtype]
    
    i=i+1
print("Column Information: ")
new_df
# Out:
# Column Information:
#              ColumnName  Null_Count_% Distinct_Values         Min        Mean  \
# 0                     1      0.000000             114     1.90349      5.2807
# 1                     2      0.000000             114     1.73177     5.30082
# 2                     3      0.000000             114       1.125     1.93475
# 3                     4      0.000000             114     1.20009     1.73201
# 4                     5      0.000000              22           0     3.12343
# 5                     6      0.000000             114     1.82251     4.54863
# 6                     7      0.000000             114     2.20697     6.23712
# 7                     8      0.000000             114     2.89223     7.70217
# 8                     9      0.000000             114     1.72988      5.9425
# 9                    10      0.000000             114     1.63924     2.77038
# 10                   11      0.000000             109           0     8.24307
# 11                   12      0.000000             114     2.39096     4.28459
# 12                   13      0.000000             114     2.49066     10.0644
# 13                   14      0.000000             114     2.59632     6.53116
# 14                   15      0.000000             114     1.72988     7.12068
# 15                   16      0.000000             114      2.0912     4.16515
# 16                   17      0.000000             114     2.03094     3.71004
# 17                   18      0.000000             114     1.77105     4.26779
# 18                   19      0.000000              75           0     12.3982
# 19                   20      0.000000             114     2.77677      6.8176
# 20                   21      0.000000              62           0     7.26043
# 21                   22      0.000000             114     2.13386      5.1444
# 22                   23      0.000000             114     1.36353     2.39712
# 23                   24      0.000000             114     1.41853     2.40984
# 24                   25      0.000000             114     2.08049     3.59178
# 25                   26      0.000000             114      2.9299     4.96335
# 26                   27      0.000000             114     2.77677     6.01058
# 27                   28      0.000000             114     1.16667     2.26278
# 28                   29      0.000000             114     1.93302     4.12465
# 29                   30      0.000000             114     1.86197     3.83001
# 30                   31      0.000000             114     2.28109     5.58209
# 31                   32      0.000000              43           0     5.11984
# 32                   33      0.000000             114     10.4254     20.0839
# 33                   34      0.000000             114     1.75208     6.08306
# 34                   35      0.000000             114     1.67029     3.76068
# 35                   36      0.000000             103           0     6.96444
# 36                   37      0.000000             114     2.27493     5.81002
# 37                   38      0.000000             114      1.6911     4.13919
# 38                   39      0.000000             114     1.33492      2.6363
# 39                   40      0.000000               1           0           0
# 2696                CCI      0.877193              38       74.29     100.313
# 2697                Sex      0.000000               2           0    0.561404
# 2698                Age      0.000000              12          18      21.807
# 2699       Subject_type      0.000000               3           0    0.587719
# 2700               FSIQ      0.000000              48          86      119.43
# 2701                CAQ      0.877193              42           1     17.8142
# 2702          Neuroticm      0.000000              37           0     17.6053
# 2703       Extraversion      0.000000              26           9     30.2456
# 2704           Openness      0.000000              26          17     33.9298
# 2705      Agreeableness      0.000000              28          15     31.9211
# 2706  Conscientiousness      0.000000              26          17     32.7632
#
#              Max    dtype
# 0        15.6373  float64
# 1        8.51535  float64
# 2         3.9928  float64
# 3        3.03009  float64
# 4        23.5174  float64
# 5        15.3951  float64
# 6        17.4312  float64
# 7        21.3827  float64
# 8        16.9316  float64
# 9        5.87915  float64
# 10         22.12  float64
# 11       8.10213  float64
# 12       23.4296  float64
# 13       15.2796  float64
# 14       22.8911  float64
# 15       14.5027  float64
# 16       8.62714  float64
# 17       8.14695  float64
# 18       39.9626  float64
# 19       15.3903  float64
# 20       30.0246  float64
# 21       15.8951  float64
# 22       6.15134  float64
# 23         5.547  float64
# 24       7.42476  float64
# 25       7.66764  float64
# 26       13.8272  float64
# 27       4.68229  float64
# 28       8.14927  float64
# 29       10.3102  float64
# 30         13.41  float64
# 31       31.7318  float64
# 32        31.244  float64
# 33       19.4425  float64
# 34       7.46786  float64
# 35       19.9597  float64
# 36       12.2845  float64
# 37       11.8063  float64
# 38       5.28423  float64
# 39             0    int64
# 40       14.7308  float64
# 41       12.8773  float64
# 42       14.2675  float64
# 43       15.1066  float64
# 44       13.0036  float64
# 45       10.4661  float64
# 46       18.8941  float64
# 47       18.4324  float64
# 48       18.0751  float64
# 49       16.4403  float64
# 50       13.1904  float64
# 51       9.98731  float64
# 52       15.5977  float64
# 53       17.7397  float64
# 54       16.2046  float64
# 55       7.34593  float64
# 56       13.5123  float64
# 57       6.79838  float64
# 58        9.8872  float64
# 59       11.9467  float64
# 60       14.0785  float64
# 61       13.0296  float64
# 62       9.48482  float64
# 63       10.7884  float64
# 64       18.6787  float64
# 65       17.4138  float64
# 66       14.8129  float64
# 67       16.0065  float64
# 68       18.8855  float64
# 69       3.98579  float64
# 70       7.37254  float64
# 71       8.59624  float64
# 72       13.3835  float64
# 73       3.95779  float64
# 74       4.04882  float64
# 75       2.94658  float64
# 76       3.21051  float64
# 77       5.77152  float64
# 78       7.86741  float64
# 79       5.99855  float64
# 80       5.31282  float64
# 81             0    int64
# 82       3.44297  float64
# 83       5.10723  float64
# 84       5.24693  float64
# 85       5.23209  float64
# 86             0    int64
# 87       3.76801  float64
# 88       6.08766  float64
# 89       4.11651  float64
# 90       7.13201  float64
# 91       5.65755  float64
# 92       7.03336  float64
# 93       3.57286  float64
# 94       5.95198  float64
# 95       8.69013  float64
# 96       4.87664  float64
# 97        3.4928  float64
# 98       2.86943  float64
# 99             0    int64
# 100            0    int64
# 101      3.35521  float64
# 102      16.8194  float64
# 103      8.09082  float64
# 104      3.29661  float64
# 105      7.02839  float64
# 106      8.32868  float64
# 107            0    int64
# 108      9.28111  float64
# 109      3.71219  float64
# 110      3.32098  float64
# 111      3.84337  float64
# 112      8.77879  float64
# 113      2.85275  float64
# 114      2.42543  float64
# 115      2.27827  float64
# 116      2.34928  float64
# 117      3.36486  float64
# 118      8.40963  float64
# 119      6.83623  float64
# 120      2.80628  float64
# 121            0    int64
# 122      2.33709  float64
# 123      1.97031  float64
# 124      4.85799  float64
# ...          ...      ...
# 2582   0.0174744  float64
# 2583   0.0251689  float64
# 2584    0.020075  float64
# 2585   0.0208006  float64
# 2586   0.0179263  float64
# 2587   0.0132694  float64
# 2588  0.00728837  float64
# 2589   0.0206096  float64
# 2590   0.0298637  float64
# 2591   0.0212292  float64
# 2592   0.0169197  float64
# 2593   0.0248496  float64
# 2594   0.0254645  float64
# 2595   0.0130886  float64
# 2596    0.019573  float64
# 2597   0.0202714  float64
# 2598   0.0185701  float64
# 2599   0.0195084  float64
# 2600   0.0271323  float64
# 2601   0.0176219  float64
# 2602   0.0186642  float64
# 2603   0.0172107  float64
# 2604   0.0184744  float64
# 2605   0.0173183  float64
# 2606   0.0217043  float64
# 2607   0.0223319  float64
# 2608   0.0197302  float64
# 2609    0.014117  float64
# 2610   0.0183186  float64
# 2611   0.0166104  float64
# 2612   0.0209997  float64
# 2613   0.0245183  float64
# 2614   0.0246276  float64
# 2615   0.0262086  float64
# 2616   0.0186928  float64
# 2617   0.0185973  float64
# 2618    0.026733  float64
# 2619   0.0198186  float64
# 2620     0.01963  float64
# 2621   0.0198842  float64
# 2622   0.0144751  float64
# 2623  0.00756316  float64
# 2624    0.016517  float64
# 2625     85.4485  float64
# 2626      157.62  float64
# 2627     157.156  float64
# 2628     119.362  float64
# 2629     104.584  float64
# 2630     272.824  float64
# 2631     208.974  float64
# 2632     162.939  float64
# 2633     160.882  float64
# 2634     154.543  float64
# 2635     119.653  float64
# 2636     189.908  float64
# 2637     142.863  float64
# 2638     183.061  float64
# 2639     188.212  float64
# 2640     176.679  float64
# 2641     173.766  float64
# 2642     165.834  float64
# 2643      160.89  float64
# 2644     399.854  float64
# 2645     203.442  float64
# 2646     239.533  float64
# 2647     158.816  float64
# 2648     145.523  float64
# 2649     127.165  float64
# 2650     135.054  float64
# 2651     158.188  float64
# 2652     191.461  float64
# 2653     119.996  float64
# 2654     132.137  float64
# 2655     143.717  float64
# 2656     171.072  float64
# 2657     317.185  float64
# 2658      284.52  float64
# 2659     181.919  float64
# 2660     85.3618  float64
# 2661     143.966  float64
# 2662     148.769  float64
# 2663       132.8  float64
# 2664     107.236  float64
# 2665     344.478  float64
# 2666     195.805  float64
# 2667     172.696  float64
# 2668     166.382  float64
# 2669     176.289  float64
# 2670      110.34  float64
# 2671     166.342  float64
# 2672     170.146  float64
# 2673     212.961  float64
# 2674     172.042  float64
# 2675     191.308  float64
# 2676     154.369  float64
# 2677     159.939  float64
# 2678     184.875  float64
# 2679     360.083  float64
# 2680     197.671  float64
# 2681     233.602  float64
# 2682     188.795  float64
# 2683     146.046  float64
# 2684     118.575  float64
# 2685     110.116  float64
# 2686     154.779  float64
# 2687     155.011  float64
# 2688     121.887  float64
# 2689     145.934  float64
# 2690     175.611  float64
# 2691     155.599  float64
# 2692      297.21  float64
# 2693      284.51  float64
# 2694      264.29  float64
# 2695          Na   object
# 2696      124.37  float64
# 2697           1    int64
# 2698          29    int64
# 2699           2    int64
# 2700         144    int64
# 2701         124  float64
# 2702          43    int64
# 2703          45    int64
# 2704          45    int64
# 2705          44    int64
# 2706          45    int64
#
# [2707 rows x 7 columns]

# %%
# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation equal to 1
to_drop = [column for column in upper.columns if any(upper[column] == 1)]

# %%
len(to_drop)
# Out:
# 47

# %%
# Drop features 
df = df.drop(df[to_drop], axis=1)

# %%
df.shape
# Out:
# (114, 2660)

# %%
feature_name = df.columns.tolist()
drop_columns = feature_name[-13:]

# %%
y = df[target_variable]
X = df.drop(labels=drop_columns, axis = 1)
feature_name = X.columns.tolist()

# %%
# PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 61)
pca.fit(X)
print("Variance Preserved:",pca.explained_variance_ratio_.sum())
p = pca.transform(X)
dataset = pd.DataFrame(p)
dataset[target_variable] = df[target_variable]
dataset.to_pickle("BrainDataPCA.pkl")
# Out:
# Variance Preserved: 0.9561552483232446

# %% [markdown]
# # Pearson Correlation

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-250:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 250 selected features

# %% [markdown]
# # Chi-2

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=250)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=250, score_func=<function chi2 at 0x0000022D2A0EE268>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 250 selected features

# %% [markdown]
# # Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=250, step=20, verbose=5)
rfe_selector.fit(X_norm, y)
# Out:
# Fitting estimator with 2647 features.
# Fitting estimator with 2627 features.
# Fitting estimator with 2607 features.
# Fitting estimator with 2587 features.
# Fitting estimator with 2567 features.
# Fitting estimator with 2547 features.
# Fitting estimator with 2527 features.
# Fitting estimator with 2507 features.
# Fitting estimator with 2487 features.
# Fitting estimator with 2467 features.
# Fitting estimator with 2447 features.
# Fitting estimator with 2427 features.
# Fitting estimator with 2407 features.
# Fitting estimator with 2387 features.
# Fitting estimator with 2367 features.
# Fitting estimator with 2347 features.
# Fitting estimator with 2327 features.
# Fitting estimator with 2307 features.
# Fitting estimator with 2287 features.
# Fitting estimator with 2267 features.
# Fitting estimator with 2247 features.
# Fitting estimator with 2227 features.
# Fitting estimator with 2207 features.
# Fitting estimator with 2187 features.
# Fitting estimator with 2167 features.
# Fitting estimator with 2147 features.
# Fitting estimator with 2127 features.
# Fitting estimator with 2107 features.
# Fitting estimator with 2087 features.
# Fitting estimator with 2067 features.
# Fitting estimator with 2047 features.
# Fitting estimator with 2027 features.
# Fitting estimator with 2007 features.
# Fitting estimator with 1987 features.
# Fitting estimator with 1967 features.
# Fitting estimator with 1947 features.
# Fitting estimator with 1927 features.
# Fitting estimator with 1907 features.
# Fitting estimator with 1887 features.
# Fitting estimator with 1867 features.
# Fitting estimator with 1847 features.
# Fitting estimator with 1827 features.
# Fitting estimator with 1807 features.
# Fitting estimator with 1787 features.
# Fitting estimator with 1767 features.
# Fitting estimator with 1747 features.
# Fitting estimator with 1727 features.
# Fitting estimator with 1707 features.
# Fitting estimator with 1687 features.
# Fitting estimator with 1667 features.
# Fitting estimator with 1647 features.
# Fitting estimator with 1627 features.
# Fitting estimator with 1607 features.
# Fitting estimator with 1587 features.
# Fitting estimator with 1567 features.
# Fitting estimator with 1547 features.
# Fitting estimator with 1527 features.
# Fitting estimator with 1507 features.
# Fitting estimator with 1487 features.
# Fitting estimator with 1467 features.
# Fitting estimator with 1447 features.
# Fitting estimator with 1427 features.
# Fitting estimator with 1407 features.
# Fitting estimator with 1387 features.
# Fitting estimator with 1367 features.
# Fitting estimator with 1347 features.
# Fitting estimator with 1327 features.
# Fitting estimator with 1307 features.
# Fitting estimator with 1287 features.
# Fitting estimator with 1267 features.
# Fitting estimator with 1247 features.
# Fitting estimator with 1227 features.
# Fitting estimator with 1207 features.
# Fitting estimator with 1187 features.
# Fitting estimator with 1167 features.
# Fitting estimator with 1147 features.
# Fitting estimator with 1127 features.
# Fitting estimator with 1107 features.
# Fitting estimator with 1087 features.
# Fitting estimator with 1067 features.
# Fitting estimator with 1047 features.
# Fitting estimator with 1027 features.
# Fitting estimator with 1007 features.
# Fitting estimator with 987 features.
# Fitting estimator with 967 features.
# Fitting estimator with 947 features.
# Fitting estimator with 927 features.
# Fitting estimator with 907 features.
# Fitting estimator with 887 features.
# Fitting estimator with 867 features.
# Fitting estimator with 847 features.
# Fitting estimator with 827 features.
# Fitting estimator with 807 features.
# Fitting estimator with 787 features.
# Fitting estimator with 767 features.
# Fitting estimator with 747 features.
# Fitting estimator with 727 features.
# Fitting estimator with 707 features.
# Fitting estimator with 687 features.
# Fitting estimator with 667 features.
# Fitting estimator with 647 features.
# Fitting estimator with 627 features.
# Fitting estimator with 607 features.
# Fitting estimator with 587 features.
# Fitting estimator with 567 features.
# Fitting estimator with 547 features.
# Fitting estimator with 527 features.
# Fitting estimator with 507 features.
# Fitting estimator with 487 features.
# Fitting estimator with 467 features.
# Fitting estimator with 447 features.
# Fitting estimator with 427 features.
# Fitting estimator with 407 features.
# Fitting estimator with 387 features.
# Fitting estimator with 367 features.
# Fitting estimator with 347 features.
# Fitting estimator with 327 features.
# Fitting estimator with 307 features.
# Fitting estimator with 287 features.
# Fitting estimator with 267 features.
# RFE(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                  fit_intercept=True, intercept_scaling=1,
#                                  l1_ratio=None, max_iter=100,
#                                  multi_class='warn', n_jobs=None, penalty='l2',
#                                  random_state=None, solver='warn', tol=0.0001,
#                                  verbose=0, warm_start=False),
#     n_features_to_select=250, step=20, verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 250 selected features

# %% [markdown]
# # Logistic Regression (Select from model)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l1"), threshold='0.00000001*median')
embeded_lr_selector.fit(X_norm, y)
# Out:
# SelectFromModel(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                              dual=False, fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='warn',
#                                              n_jobs=None, penalty='l1',
#                                              random_state=None, solver='warn',
#                                              tol=0.0001, verbose=0,
#                                              warm_start=False),
#                 max_features=None, norm_order=1, prefit=False,
#                 threshold='0.00000001*median')

# %%
embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 2647 selected features

# %% [markdown]
# # Random forest (Select from model)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold=0.0014)
embeded_rf_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini',
#                                                  max_depth=None,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100, n_jobs=None,
#                                                  oob_score=False,
#                                                  random_state=None, verbose=0,
#                                                  warm_start=False),
#                 max_features=None, norm_order=1, prefit=False,
#                 threshold=0.0014)

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 232 selected features

# %% [markdown]
# # LightGBM

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

embeded_lgb_selector = SelectFromModel(lgbc, max_features=250)
embeded_lgb_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=LGBMClassifier(boosting_type='gbdt',
#                                          class_weight=None,
#                                          colsample_bytree=0.2,
#                                          importance_type='split',
#                                          learning_rate=0.05, max_depth=-1,
#                                          min_child_samples=20,
#                                          min_child_weight=40,
#                                          min_split_gain=0.01, n_estimators=500,
#                                          n_jobs=-1, num_leaves=32,
#                                          objective=None, random_state=None,
#                                          reg_alpha=3, reg_lambda=1, silent=True,
#                                          subsample=1.0,
#                                          subsample_for_bin=200000,
#                                          subsample_freq=0),
#                 max_features=250, norm_order=1, prefit=False, threshold=None)

# %%
embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
# Out:
# 250 selected features

# %% [markdown]
# # Conclusion

# %%
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 
                                    'RandomForest':embeded_rf_support, 'LightGBM':embeded_lgb_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df[['Pearson', 'Chi-2', 'RFE', 'RandomForest', 'LightGBM']], axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(250)
# Out:
#      Feature  Pearson  Chi-2    RFE  RandomForest  LightGBM  Total
# 1       2610     True   True   True          True     False      4
# 2       2186     True   True   True          True     False      4
# 3       2133     True   True   True          True     False      4
# 4       1953     True   True   True          True     False      4
# 5       1943     True   True   True          True     False      4
# 6       1482     True   True   True          True     False      4
# 7        978     True   True   True          True     False      4
# 8        967     True   True   True          True     False      4
# 9        676     True   True   True          True     False      4
# 10       415     True   True   True          True     False      4
# 11       218     True  False   True          True      True      4
# 96        77     True  False   True         False      True      3
# 97        61     True  False  False          True      True      3
# 98        32     True   True  False         False      True      3
# 99        17     True  False   True         False      True      3
# 100       10     True  False  False          True      True      3
# 101     2687     True  False  False          True     False      2
# 102     2673     True  False  False          True     False      2
# 103     2641     True  False  False          True     False      2
# 104     2633     True  False   True         False     False      2
# 105     2617     True  False  False          True     False      2
# 106     2601     True  False  False          True     False      2
# 107     2591     True  False  False          True     False      2
# 108     2582     True  False   True         False     False      2
# 109     2565     True  False  False          True     False      2
# 110     2563     True  False   True         False     False      2
# 111     2562    False  False   True          True     False      2
# 112     2537    False  False   True          True     False      2
# 113     2533     True  False  False          True     False      2
# 114     2530     True  False   True         False     False      2
# 115     2513     True  False  False          True     False      2
# 116     2498     True  False  False          True     False      2
# 117     2461     True  False  False          True     False      2
# 118     2455     True  False  False          True     False      2
# 119     2453    False  False   True          True     False      2
# 120     2431     True  False  False          True     False      2
# 121     2381     True  False  False          True     False      2
# 122     2364     True  False   True         False     False      2
# 123     2363     True  False  False          True     False      2
# 124     2354     True  False   True         False     False      2
# 125     2350     True  False   True         False     False      2
# 126     2338    False   True   True         False     False      2
# 127     2325    False   True   True         False     False      2
# 128     2273     True  False  False          True     False      2
# 129     2256    False  False   True          True     False      2
# 130     2224     True  False   True         False     False      2
# 131     2223     True  False  False          True     False      2
# 132     2219     True  False  False          True     False      2
# 133     2215     True  False   True         False     False      2
# 134     2183     True  False  False          True     False      2
# 135     2169     True  False  False          True     False      2
# 136     2130     True  False  False          True     False      2
# 137     2128     True  False   True         False     False      2
# 138     2119     True  False  False          True     False      2
# 139     2116     True  False   True         False     False      2
# 140     2090     True  False   True         False     False      2
# 141     2078    False  False   True          True     False      2
# 142     2048     True   True  False         False     False      2
# 143     2030    False   True   True         False     False      2
# 144     1975     True  False   True         False     False      2
# 145     1974     True  False  False          True     False      2
# 146     1960     True  False  False          True     False      2
# 147     1958     True  False  False          True     False      2
# 148     1946     True  False   True         False     False      2
# 149     1912     True  False  False          True     False      2
# 150     1909     True  False   True         False     False      2
# 151     1907    False   True   True         False     False      2
# 152     1905     True  False  False          True     False      2
# 153     1889     True  False  False          True     False      2
# 154     1870     True  False  False          True     False      2
# 155     1856     True  False   True         False     False      2
# 156     1849     True  False  False          True     False      2
# 157     1843     True  False  False          True     False      2
# 158     1832     True  False  False          True     False      2
# 159     1828     True  False   True         False     False      2
# 160     1817    False   True   True         False     False      2
# 161     1694     True   True  False         False     False      2
# 162     1691    False   True   True         False     False      2
# 163     1689    False   True   True         False     False      2
# 164     1688     True   True  False         False     False      2
# 165     1684     True   True  False         False     False      2
# 166     1681    False   True   True         False     False      2
# 167     1635     True   True  False         False     False      2
# 168     1624    False  False   True          True     False      2
# 169     1606    False   True   True         False     False      2
# 170     1601    False  False   True          True     False      2
# 171     1595    False   True   True         False     False      2
# 172     1575    False  False   True          True     False      2
# 173     1514     True   True  False         False     False      2
# 174     1426    False  False   True          True     False      2
# 175     1420    False   True   True         False     False      2
# 176     1413     True  False   True         False     False      2
# 177     1388    False   True   True         False     False      2
# 178     1376    False   True   True         False     False      2
# 179     1365     True   True  False         False     False      2
# 180     1322     True  False   True         False     False      2
# 181     1306     True   True  False         False     False      2
# 182     1289     True  False  False          True     False      2
# 183     1261    False   True   True         False     False      2
# 184     1246    False   True   True         False     False      2
# 185     1231    False  False   True          True     False      2
# 186     1230    False   True   True         False     False      2
# 187     1100    False   True   True         False     False      2
# 188     1077     True  False   True         False     False      2
# 189     1063    False   True   True         False     False      2
# 190     1059     True  False   True         False     False      2
# 191     1048     True  False   True         False     False      2
# 192     1043     True  False  False          True     False      2
# 193      992     True  False   True         False     False      2
# 194      974     True   True  False         False     False      2
# 195      944     True  False   True         False     False      2
# 196      942     True   True  False         False     False      2
# 197      940     True  False  False          True     False      2
# 198      915    False   True   True         False     False      2
# 199      908     True  False  False          True     False      2
# 200      885     True   True  False         False     False      2
# 201      864    False   True   True         False     False      2
# 202      846     True   True  False         False     False      2
# 203      805     True  False   True         False     False      2
# 204      789     True  False  False          True     False      2
# 205      787     True  False   True         False     False      2
# 206      765     True   True  False         False     False      2
# 207      744    False   True   True         False     False      2
# 208      723    False  False   True          True     False      2
# 209      661     True  False   True         False     False      2
# 210      652     True  False   True         False     False      2
# 211      635     True   True  False         False     False      2
# 212      628     True   True  False         False     False      2
# 213      621     True   True  False         False     False      2
# 214      600     True  False  False          True     False      2
# 215      598     True  False   True         False     False      2
# 216      586     True  False   True         False     False      2
# 217      493    False   True   True         False     False      2
# 218      471     True  False  False          True     False      2
# 219      468     True  False   True         False     False      2
# 220      466     True  False   True         False     False      2
# 221      457    False   True   True         False     False      2
# 222      328     True  False  False          True     False      2
# 223      327     True  False  False          True     False      2
# 224      309    False   True   True         False     False      2
# 225      292     True  False  False          True     False      2
# 226      283     True  False   True         False     False      2
# 227      279    False  False   True          True     False      2
# 228      274    False  False   True          True     False      2
# 229      252    False  False  False          True      True      2
# 230      237    False  False   True         False      True      2
# 231      227    False  False  False          True      True      2
# 232      221    False  False  False          True      True      2
# 233      220    False  False   True         False      True      2
# 234      217    False  False  False          True      True      2
# 235      216    False  False  False          True      True      2
# 236      215     True  False  False         False      True      2
# 237      206    False   True  False         False      True      2
# 238      188    False  False  False          True      True      2
# 239      185    False   True  False         False      True      2
# 240      182    False  False   True         False      True      2
# 241      179    False   True  False         False      True      2
# 242      177    False   True  False         False      True      2
# 243      170    False  False  False          True      True      2
# 244      161     True  False  False         False      True      2
# 245      153    False  False  False          True      True      2
# 246      149     True  False  False         False      True      2
# 247      144    False   True  False         False      True      2
# 248      143    False   True  False         False      True      2
# 249      132    False   True  False         False      True      2
# 250      116    False   True  False         False      True      2

# %%
selected_feature = feature_selection_df.loc[feature_selection_df['Total'] > 2]['Feature']

# %%
EBC = 0
NBC = 0
C = 0
PR = 0
SOC = 0

for feat in selected_feature:
    if int(feat) <= 2417:
        EBC += 1
    elif int(feat) <= 2487:
        NBC += 1
    elif int(feat) <= 2557:
        C += 1
    elif int(feat) <= 2627:
        PR += 1
    elif int(feat) <= 2697:
        SOC += 1

print(EBC, NBC, C, PR, SOC)
# Out:
# 93 0 2 3 2

# %%
# 3  2.194028   0.0  2.404720  2.702831  6.122042  0.000000  0.000000  5.541706
# 4  3.100738   0.0  1.847056  2.168119  7.675786  1.892932  0.000000  5.082093
#
#        1556      1542      1502      1498      1481      1471  1417      1368  \
# 0  3.495813  3.075507  5.014902  1.328907  4.418448  3.629099   0.0  0.000000
# 1  7.619814  0.000000  0.000000  0.000000  0.000000  4.932685   0.0  0.000000
# 2  4.445143  0.000000  3.475931  2.040115  2.248866  2.954233   0.0  0.000000
# 3  4.964638  0.000000  0.000000  0.000000  2.735060  2.409566   0.0  0.000000
# 4  6.052028  0.000000  3.636815  0.000000  2.116969  2.044765   0.0  2.225213
#
#        1362      1358      1316      1224  1168      1096      1083  1057  \
# 0  1.906266  3.916425  2.791544  1.318648   0.0  3.647468  3.386674   0.0
# 1  0.000000  5.837766  0.000000  0.000000   0.0  0.000000  5.295991   0.0
# 2  3.302662  4.426983  0.000000  0.000000   0.0  0.000000  5.236922   0.0
# 3  0.000000  3.028433  0.000000  0.000000   0.0  0.000000  4.508990   0.0
# 4  2.946333  0.000000  0.000000  0.000000   0.0  5.488454  3.628981   0.0
#
#        1044      1010      973       954       916       809        783   \
# 0  1.504314  3.265053  2.736703  3.270960  1.868995  4.513250   6.767530
# 1  1.119048  7.830897  0.000000  0.000000  0.000000  0.000000  11.068196
# 2  2.461735  6.848986  0.000000  0.000000  0.000000  5.118641  14.923329
# 3  1.743642  0.000000  0.000000  0.000000  0.000000  0.000000  10.934636
# 4  1.034483  1.938366  0.000000  4.297622  0.000000  0.000000   0.000000
#
#        767       733        728       727   685       649       634   \
# 0  0.000000  0.000000   5.368282  1.722419   0.0  0.000000  2.850283
# 1  0.000000  0.000000   0.000000  2.575433   0.0  8.328769  0.000000
# 2  0.000000  0.000000   0.000000  2.227870   0.0  5.345314  0.000000
# 3  0.000000  7.007956  16.655148  2.301561   0.0  6.216737  0.000000
# 4  3.571587  0.000000   6.544528  1.360050   0.0  5.388710  3.051722
#
#        518       500       465      411       331       255       222   \
# 0  5.955749  0.000000  1.560447  2.35122  3.337057  4.491534  4.584237
# 1  0.000000  0.000000  3.003074  0.00000  0.000000  5.580749  0.000000
# 2  0.000000  0.000000  2.388205  0.00000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  3.358226  0.00000  0.000000  0.000000  0.000000
# 4  0.000000  3.013701  1.915438  0.00000  0.000000  0.000000  0.000000
#
#        194       174   118   80        77        61         32        17    \
# 0  2.573824  2.473824   0.0   0.0  1.349298  5.913957   0.000000  2.833179
# 1  3.941522  2.126682   0.0   0.0  1.291667  4.760521   0.000000  3.039218
# 2  2.318021  2.419247   0.0   0.0  1.499687  4.334599   0.000000  3.269311
# 3  5.746676  3.921323   0.0   0.0  1.271429  4.879470  15.246152  2.740998
# 4  4.198456  4.860758   0.0   0.0  1.363462  6.260437  29.027043  2.458179
#
#        10
# 0  2.644199
# 1  2.921938
# 2  2.402819
# 3  2.879263
# 4  2.570783

# %%
# add the target variable in our data so that we apply machine learning algorithms to our data set.
df_selected[target_variable] = df[target_variable]
df_selected.shape
# Out:
# (114, 101)

# %%
df_selected.to_pickle('Brain_SelectedData.pkl')
