# %%
import pandas as pd

# %%
df_upper = pd.read_csv('upper_result.csv')
df_upper
# Out:
#    Model     Target Value  Accuracy
# 0     LR              Sex        71
# 1     LR             FSIQ        62
# 2     LR      Neuroticism        56
# 3     LR     Extraversion        52
# 4     LR         Openness        52
# 5     LR    Agreeableness        53
# 6     LR  Concietiousness        49
# 7     RF              Sex        80
# 8     RF             FSIQ        45
# 9     RF      Neuroticism        55
# 10    RF     Extraversion        46
# 11    RF         Openness        46
# 12    RF    Agreeableness        48
# 13    RF  Concietiousness        43
# 14   SVM              Sex        73
# 15   SVM             FSIQ        60
# 16   SVM      Neuroticism        55
# 17   SVM     Extraversion        55
# 18   SVM         Openness        55
# 19   SVM    Agreeableness        73
# 20   SVM  Concietiousness        36
# 21   KNN              Sex        83
# 22   KNN             FSIQ        52
# 23   KNN      Neuroticism        59
# 24   KNN     Extraversion        56
# ...

# %%
df_extracted =  pd.read_csv('extracted_result.csv')
df_extracted
# Out:
#    Model     Target Value  Accuracy
# 0     LR              Sex        88
# 1     LR             FSIQ        65
# 2     LR      Neuroticism        68
# 3     LR     Extraversion        65
# 4     LR         Openness        65
# 5     LR    Agreeableness        70
# 6     LR  Concietiousness        65
# 7     RF              Sex        69
# 8     RF             FSIQ        50
# 9     RF      Neuroticism        54
# 10    RF     Extraversion        60
# 11    RF         Openness        51
# 12    RF    Agreeableness        48
# 13    RF  Concietiousness        59
# 14   SVM              Sex        82
# 15   SVM             FSIQ        68
# 16   SVM      Neuroticism        67
# 17   SVM     Extraversion        64
# 18   SVM         Openness        65
# 19   SVM    Agreeableness        59
# 20   SVM  Concietiousness        64
# 21   KNN              Sex        80
# 22   KNN             FSIQ        64
# 23   KNN      Neuroticism        54
# 24   KNN     Extraversion        52
# ...

# %%
import seaborn as sns
fig = plt.figure()
plt.figure(figsize=(10, 7))
ax = sns.lineplot(x='Target Value', y = 'Accuracy', hue='Model', data = df_extracted)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

fig.savefig('extracted_result.png')

# %%
import seaborn as sns
plt.figure(figsize=(10, 7))
ax = sns.lineplot(x='Target Value', y = 'Accuracy', hue='Model', data = df_upper)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
plt.savefig('upper_result.png')
